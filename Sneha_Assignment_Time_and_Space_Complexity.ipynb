# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha8126/Python-Assignment/blob/main/Sneha_Assignment_Time_and_Space_Complexity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <u>While doing this assignment only use those concepts which have been taught till now</u>

# %% [markdown]
# # Problem 1
#
# Write a Python function which takes a string as an input and returns the reversed string as an output.
#
#
# *   Do not use any inbuilt funtion or method. Use `for` loops only.

# %%
# Write your code here

def reverse_string(input_str):
    reversed_str = ""
    for char in input_str:
        reversed_str = char + reversed_str
    return reversed_str

print(reverse_string("hello"))



# Time Complexity : ?  O(n) ===> where n is the length of the string. The loop iterates through each character exactly once.
# Space Complexity : ?  O(n)  ===> as we are creating a new string that stores n characters.
# Out:
# olleh

# %%
import time

def reverse_string(input_str):
    reversed_str = ""
    for char in input_str:
        reversed_str = char + reversed_str
    return reversed_str

my_str = "hello"

# Old time (before execution)
start_time = time.time()

# Function call
result = reverse_string(my_str)

# New time (after execution)
end_time = time.time()

print("Reversed string:", result)
print("Time taken:", end_time - start_time)
# Out:
# Reversed string: olleh
# Time taken: 5.841255187988281e-05

# %% [markdown]
# # Problem 2
#
# Write a Python function which takes a list of `n` lists as an input. Each of the `n` lists have `m` non-zero positive integers each. The function should return a list which contains `n` integers corresponding to the square of the maximum of each of the `n` lists in the list of lists.
#
# Example:
# Inputs
# ```
# n = 2
# m = 3
# list_of_lists = [[1, 2, 3], [5, 7, 6]]
# ```
# Output:
# ```
# [9, 49]
# ```
#
# *   Do not use any inbuilt funtion or method. Use `for` loops only.

# %%
# Write your code here

n = 2
m = 3
list_of_lists = [[1, 2, 3], [5, 7, 6]]

def square_of_max(list_of_lists):
    result = []

    for sublist in list_of_lists:
        current_max = sublist[0]

        for num in sublist:
            if num > current_max:
                current_max = num

        result.append(current_max * current_max)

    return result

print(square_of_max(list_of_lists))



# Time Complexity : O(n*m)
# Space Complexity : O(n)
# Out:
# [9, 49]
