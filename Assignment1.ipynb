# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha8126/Python-Assignment/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1

# %%
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation"
print(sentence.count(' ')+1)
# Out:
# 20

# %% [markdown]
# # Question 2

# %%
inputted_number = 10
print('-'*inputted_number)
# Out:
# ----------

# %% [markdown]
# # Question 3

# %%
bridge = 'rahul singh'
b = bridge.count(' ')
print(b==0)
# Out:
# False

# %%
bridge = 'mohan'
b = bridge.count(' ')
print(b==0)
# Out:
# True

# %% [markdown]
# # Question 4

# %%
user_string = 'Debris was scatterd all over the place in the densest region of Denmark'
print(user_string.lower().count('d'))
# Out:
# 4

# %% [markdown]
# # Question 5

# %%
user_string = 'madam'
b=user_string[::-1]
print(user_string==b)
# Out:
# True
