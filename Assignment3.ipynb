# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha8126/Python-Assignment/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1

# %%
temperatures = [34, 40, 29, 33, 42, 40, 39, 34, 34,33 ]

# %%
lst=sorted(list(set(temperatures)))
print(lst)
# Out:
# [29, 33, 34, 39, 40, 42]

# %%
dct={}

# %%
dct[lst[0]]=temperatures.count(lst[0])
dct[lst[1]]=temperatures.count(lst[1])
dct[lst[2]]=temperatures.count(lst[2])
dct[lst[3]]=temperatures.count(lst[3])
dct[lst[4]]=temperatures.count(lst[4])
dct[lst[5]]=temperatures.count(lst[5])

# %%
print(dct)
# Out:
# {29: 1, 33: 2, 34: 3, 39: 1, 40: 2, 42: 1}

# %%
countlst = list(dct.values())

# %%
maxcount=max(countlst)

# %%
countindex=countlst.index(maxcount)
print(countindex)
# Out:
# 2

# %%
keylist=list(dct.keys())
print(keylist)
# Out:
# [29, 33, 34, 39, 40, 42]

# %%
mode=keylist[countindex]
print(mode)
# Out:
# 34

# %% [markdown]
# # Question 2

# %%
list_of_tuples = [(10,20,30),(30,40,50),(50,60,70)]

# %%
temp_list = list(list_of_tuples[-1])
print(temp_list)
# Out:
# [50, 60, 70]

# %%
temp_list[-1] = 100
print(temp_list)
# Out:
# [50, 60, 100]

# %%
new_tuple = tuple(temp_list)
list_of_tuples[-1] = new_tuple

# %%
print(list_of_tuples)
# Out:
# [(10, 20, 30), (30, 40, 50), (50, 60, 100)]

# %% [markdown]
# # Question 3

# %%
# Default set of stop words
stop_words = {"i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that",
              "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had",
              "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because",
              "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into",
              "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out",
              "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where",
              "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no",
              "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just",
              "don", "should", "now"}

# %%
# Update the set of stop words by adding the custom stop words
custom_stop_words = ["hello","good","morning","half","yearly"]

# %%
updated_stop_words = stop_words | set(custom_stop_words)

# %%
print(updated_stop_words)
print(sorted(list(updated_stop_words)))
# Out:
# {'myself', 'her', 'it', 's', 'by', 'me', 'between', 'my', 'our', 'does', 'themselves', 'after', 'being', 'had', 'through', 'they', 'i', 'there', 'what', 't', 'under', 'until', 'as', 'nor', 'in', 'whom', 'these', 'morning', 'yourselves', 'why', 'about', 'its', 'where', 'itself', 'were', 'over', 'or', 'some', 'just', 'who', 'don', 'no', 'here', 'theirs', 'once', 'was', 'off', 'during', 'few', 'half', 'other', 'he', 'such', 'so', 'that', 'this', 'not', 'his', 'at', 'am', 'above', 'been', 'can', 'and', 'more', 'you', 'yours', 'than', 'down', 'your', 'out', 'all', 'has', 'them', 'if', 'to', 'only', 'hers', 'yourself', 'should', 'herself', 'how', 'for', 'those', 'but', 'then', 'ours', 'any', 'same', 'because', 'on', 'ourselves', 'of', 'before', 'below', 'into', 'an', 'now', 'did', 'too', 'most', 'with', 'own', 'further', 'the', 'hello', 'which', 'have', 'against', 'both', 'be', 'himself', 'we', 'is', 'she', 'while', 'when', 'do', 'yearly', 'each', 'him', 'their', 'again', 'from', 'doing', 
# ...

# %% [markdown]
# # Question 4

# %%
# Your dictionary
employee_dict = {'Name':'Sanket','Skills':['Python','Machine Learning','Deep Learning'],'Band':6.0,
                 'Promotion Year':[2016,2018,2020]}

# %%
keys_tuple = tuple(employee_dict.keys())
status_list = ['key is not available', 'key is available']
print(status_list[keys_tuple.count('Employee_ID')])
# Out:
# key is not available

# %%
employee_dict.update({'Employee_ID': 4503233})
print(employee_dict)
# Out:
# {'Name': 'Sanket', 'Skills': ['Python', 'Machine Learning', 'Deep Learning'], 'Band': 6.0, 'Promotion Year': [2016, 2018, 2020], 'Employee_ID': 4503233}

# %%
print(status_list[keys_tuple.count('Band')])
# Out:
# key is available

# %%
employee_dict.pop('Band', None)
print(employee_dict)
# Out:
# {'Name': 'Sanket', 'Skills': ['Python', 'Machine Learning', 'Deep Learning'], 'Promotion Year': [2016, 2018, 2020], 'Employee_ID': 4503233}
