# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha8126/Python-Assignment/blob/main/Day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=5
print(a+b)
# Out:
# 15

# %%
a=False
type(a)
# Out:
# bool

# %%
print(a*b)
# Out:
# 0

# %%
a=10
b=5
print(a/b)
# Out:
# 2.0

# %%
print(a//b)
# Out:
# 2

# %%
print("Hello")
# Out:
# Hello

# %%
print(a%b)
# Out:
# 0

# %%
a=3
print(a**2)
# Out:
# 9

# %%
a=2
print(a**4)
# Out:
# 16

# %%
a=(10*2)-(10/2)
print(a)
# Out:
# 15.0

# %%
rahul=10
Rahul=20
print(Rahul)
# Out:
# 20

# %%
Sneha_rajput=25
print(Sneha_rajput)
# Out:
# 25

# %%
s_1_2=5
print(s_1_2)
# Out:
# 5

# %%
a=5
b=10
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
# Out:
# False
# True
# False
# True

# %%
a=5
b=7
print(a-b)
print(a+b)
print(a*b)
print(a/b)
print(a//b)
# Out:
# -2
# 12
# 35
# 0.7142857142857143
# 0

# %%
a=5
type(a)
# Out:
# int

# %%
a=10.0
type(a)
# Out:
# float

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print("Hello Wolrd!")
# Out:
# Hello Wolrd!

# %%
#print("Hello Wolrd")

# %%
a='hello'
type(a)
# Out:
# str

# %%
a="hello"
type(a)
# Out:
# str

# %%
a="I'm good"
print(a)
# Out:
# I'm good

# %%
print(a[0])
# Out:
# I

# %%
a='Python'
print(a)
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print(a[5])
# Out:
# Python
# P
# y
# t
# h
# o
# n

# %%
print(a[-1])
print(a[-2])
print(a[-3])
print(a[-4])
print(a[-5])
print(a[-6])
# Out:
# n
# o
# h
# t
# y
# P

# %%
print(a[2:4])
# Out:
# th

# %%
b = 'String Slicing'
print(b[1:9:2])
print(b[1:9:1])
# Out:
# tigS
# tring Sl

# %%
print(a+b)
# Out:
# PythonString Slicing

# %%
print(a+' '+b)
# Out:
# Python String Slicing

# %%
print(a*10)
# Out:
# PythonPythonPythonPythonPythonPythonPythonPythonPythonPython

# %%
print((a+' ')*4)
# Out:
# Python Python Python Python

# %%
print(len(a))
print(len(b))
# Out:
# 6
# 14

# %%
print(a.lower())
print(a.upper())
# Out:
# python
# PYTHON

# %%
a='hELLO'
print(a[0].upper()+a[1:].lower())
# Out:
# Hello

# %%
a = 'method returns'
print(a.count('e'))
# Out:
# 2

# %%
print(a.find('e'))
# Out:
# 1

# %%
print(a.replace('h','c'))
# Out:
# metcod returns

# %%
print(a.replace('e','s'))
# Out:
# msthod rsturns

# %%
a=5
b=3
c=a+b
print(f'the sum of {a} and {b} is {c}')
# Out:
# the sum of 5 and 3 is 8

# %%
a = 'Python'
b = 'case'
c = 'language'
print(f'{a} is a {b} sensitive {c}')
# Out:
# Python is a case sensitive language

# %%
x = 'The sum of a and b is'
a = 10
b = 5
print(f'{x} {a+b}')
# Out:
# The sum of a and b is 15

# %% [markdown]
# Operators
# 1. Arithmetic operator
# 2. Assignment operator
# 3. Comparison operator

# %%
a = 4
b = 34
c = 12
print(a+b+c)
# Out:
# 50

# %% [markdown]
# /////////////////////////////////                   LIST                  //////////////////////////////////

# %%
a = [1,2,3.5,'hello']
type(a)
# Out:
# list

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[3])
# Out:
# 1
# 2
# 3.5
# hello

# %%
a[2]='Python'
print(a)
# Out:
# [1, 2, 'Python', 'hello']

# %%
b=[2,6,8]
print(a+b)
# Out:
# [1, 2, 'Python', 'hello', 2, 6, 8]

# %%
a.extend(b)
print(a)
# Out:
# [1, 2, 'Python', 'hello', 2, 6, 8]

# %%
print(a)
# Out:
# [1, 2, 'Python', 'hello', 2, 6, 8]

# %%
a.append(91)
print(a)
# Out:
# [1, 2, 'Python', 'hello', 2, 6, 8, 91]

# %%
b = ['hello','apple']
print(max(b))
print(min(b))
# Out:
# hello
# apple

# %%
a = [1,3,6,5,2]
print(sorted(a))
# Out:
# [1, 2, 3, 5, 6]

# %%
print(a)
# Out:
# [1, 3, 6, 5, 2]

# %%
a.pop(3)
print(a)
# Out:
# [1, 3, 6, 2]

# %%
print(a)
# Out:
# [1, 3, 6, 2]

# %%
a.remove(2)
print(a)
# Out:
# [1, 3, 6]

# %%
a.reverse()
print(a)
# Out:
# [6, 3, 1]

# %%
print(a)
# Out:
# [6, 3, 1]

# %%
print(a[::-1])
# Out:
# [1, 3, 6]

# %%
print(a)
# Out:
# [6, 3, 1]

# %%
a.reverse()
print(a)
# Out:
# [1, 3, 6]

# %%
print(a)
# Out:
# [1, 3, 6]

# %%
a = ['rahul','mohan']
b = ['kumar','singh']
c = a+b
print(len(c))
# Out:
# 4

# %%
c = [['rahul','mohan'],['kumar','singh']]
print(c)
# Out:
# [['rahul', 'mohan'], ['kumar', 'singh']]

# %%
print(len(c))
# Out:
# 2

# %%
print(c[0][0])
print(c[0][1])
# Out:
# rahul
# mohan

# %%
print(c[1][0])
print(c[1][1])
# Out:
# kumar
# singh

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(c[0][0][3])
# Out:
# u

# %% [markdown]
# ### **ASSIGNMENT-1**

# %%
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation"
print(sentence.count(' ')+1)
# Out:
# 20

# %%
a = 'hello world'
print(a.count(' ')+1)
# Out:
# 2

# %%
inputted_number = 10
print('-'*inputted_number)
# Out:
# ----------

# %%
bridge = 'rahul singh'
b = bridge.count(' ')
print(b==0)
# Out:
# False

# %%
bridge = 'mohan'
b = bridge.count(' ')
print(b==0)
# Out:
# True

# %%
user_string = 'Debris was scatterd all over the place in the densest region of Denmark'
print(user_string.lower())
# Out:
# debris was scatterd all over the place in the densest region of denmark

# %%
print(user_string.count('d'))
# Out:
# 2

# %%
print(user_string)
# Out:
# Debris was scatterd all over the place in the densest region of Denmark

# %%
print(user_string.lower().count('D'))
# Out:
# 0

# %%
print(user_string.lower().count('d'))
# Out:
# 4

# %%
user_string = 'madam'
b=user_string[::-1]
print(b)
print(user_string==b)
# Out:
# madam
# True
